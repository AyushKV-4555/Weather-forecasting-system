# %%
import numpy as np
import pandas as pd

df = pd.read_csv('/kaggle/input/weather-dataset/weatherHistory.csv')

# %%
df.shape
# Out:
# (96453, 12)

# %%
df.sample(10)
# Out:
#                       Formatted Date        Summary Precip Type  \
# 40629  2010-03-26 21:00:00.000 +0100          Clear        rain
# 81748  2015-02-08 07:00:00.000 +0100       Overcast        snow
# 49224  2011-03-20 00:00:00.000 +0100       Overcast        rain
# 58342  2012-03-04 23:00:00.000 +0100  Mostly Cloudy        rain
# 71299  2014-08-25 19:00:00.000 +0200  Partly Cloudy        rain
# 35479  2010-04-24 07:00:00.000 +0200       Overcast        rain
# 12231  2007-01-30 15:00:00.000 +0100  Mostly Cloudy        rain
# 76961  2014-11-18 21:00:00.000 +0100  Mostly Cloudy        rain
# 63066  2013-12-17 18:00:00.000 +0100       Overcast        snow
# 13849  2007-06-09 01:00:00.000 +0200  Mostly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 40629        13.911111                 13.911111      0.54            27.9013
# 81748        -2.522222                 -8.300000      0.73            19.3522
# 49224         2.777778                 -1.805556      0.96            20.6563
# 58342         1.666667                 -0.255556      0.54             6.4400
# 71299        18.861111                 18.861111      0.60             1.5939
# 35479        11.016667                 11.016667      0.77            11.0124
# 12231         7.311111                  3.727778      0.70            22.5883
# 76961         6.711111                  3.983333      0.93            14.2807
# 63066        -0.044444                 -3.172222      0.86             9.3541
# 13849        18.244444                 18.244444      0.75            10.7548
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 40629                   150.0          15.8263         0.0
# 81748                   254.0           9.6278         0.0
# 49224                    29.0           6.1985         0.0
# 58342                    80.0          16.1000         0.0
# 71299                   212.0          16.1000         0.0
# 35479                    50.0           9.9820         0.0
# 12231                   269.0          11.2700         0.0
# 76961                   131.0          15.6492         0.0
# 63066                    93.0           7.9051         0.0
# 13849                   300.0          15.8263         0.0
#
#        Pressure (millibars)                                      Daily Summary
# 40629               1013.18                       Partly cloudy until evening.
# 81748               1010.84  Breezy starting in the afternoon continuing un...
# 49224               1023.60                       Overcast throughout the day.
# 58342               1022.30             Partly cloudy starting in the morning.
# 71299               1018.00                  Partly cloudy throughout the day.
# 35479               1017.98                  Mostly cloudy throughout the day.
# 12231               1017.42                       Mostly cloudy until evening.
# 76961               1012.27                         Mostly cloudy until night.
# 63066               1036.68  Foggy starting overnight continuing until morn...
# 13849               1016.32                  Partly cloudy throughout the day.

# %%
df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 24

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (96429, 12)

# %%
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %%
df.to_csv("weather_prediction_dataset.csv", index=False)
